# %% [markdown]
# # Student Alcohol Consumption

# %% [markdown]
# ### Introduction:
#
# This time you will download a dataset from the UCI.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/thieu1995/csv-files/main/data/pandas/student-mat.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called df.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/thieu1995/csv-files/main/data/pandas/student-mat.csv',index_col=0,low_memory=False)
df
# Out:
#        sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# school
# GP       F   18       U     GT3       A     4     4   at_home   teacher
# GP       F   17       U     GT3       T     1     1   at_home     other
# GP       F   15       U     LE3       T     1     1   at_home     other
# GP       F   15       U     GT3       T     4     2    health  services
# GP       F   16       U     GT3       T     3     3     other     other
# ...     ..  ...     ...     ...     ...   ...   ...       ...       ...
# MS       M   20       U     LE3       A     2     2  services  services
# MS       M   17       U     LE3       T     3     1  services  services
# MS       M   21       R     GT3       T     1     1     other     other
# MS       M   18       R     LE3       T     3     2  services     other
# MS       M   19       U     LE3       T     1     1     other   at_home
#
#         reason  ... famrel  freetime  goout  Dalc Walc health absences  G1  \
# school          ...
# GP      course  ...      4         3      4     1    1      3        6   5
# GP      course  ...      5         3      3     1    1      3        4   5
# GP       other  ...      4         3      2     2    3      3       10   7
# GP        home  ...      3         2      2     1    1      5        2  15
# GP        home  ...      4         3      2     1    2      5        4   6
# ...        ...  ...    ...       ...    ...   ...  ...    ...      ...  ..
# MS      course  ...      5         5      4     4    5      4       11   9
# MS      course  ...      2         4      5     3    4      2        3  14
# MS      course  ...      5         5      3     3    3      3        3  10
# MS      course  ...      4         4      1     3    4      5        0  11
# MS      course  ...      3         2      3     3    3      5        5   8
#
#         G2  G3
# school
# GP       6   6
# GP       5   6
# GP       8  10
# GP      14  15
# GP      10  10
# ...     ..  ..
# MS       9   9
# MS      16  16
# MS       8   7
# MS      12  10
# MS       9   9
#
# [395 rows x 32 columns]

# %% [markdown]
# ### Step 4. For the purpose of this exercise slice the dataframe from 'school' until the 'guardian' column

# %%
stud_alcoh = df.loc[:,:'guardian']
stud_alcoh
# Out:
#        sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# school
# GP       F   18       U     GT3       A     4     4   at_home   teacher
# GP       F   17       U     GT3       T     1     1   at_home     other
# GP       F   15       U     LE3       T     1     1   at_home     other
# GP       F   15       U     GT3       T     4     2    health  services
# GP       F   16       U     GT3       T     3     3     other     other
# ...     ..  ...     ...     ...     ...   ...   ...       ...       ...
# MS       M   20       U     LE3       A     2     2  services  services
# MS       M   17       U     LE3       T     3     1  services  services
# MS       M   21       R     GT3       T     1     1     other     other
# MS       M   18       R     LE3       T     3     2  services     other
# MS       M   19       U     LE3       T     1     1     other   at_home
#
#         reason guardian
# school
# GP      course   mother
# GP      course   father
# GP       other   mother
# GP        home   mother
# GP        home   father
# ...        ...      ...
# MS      course    other
# MS      course   mother
# MS      course    other
# MS      course   mother
# MS      course   father
#
# [395 rows x 11 columns]

# %% [markdown]
# ### Step 5. Create a lambda function that will capitalize strings.

# %%
capitalize = lambda x:x.capitalize()
capitalize
# Out:
# <function __main__.<lambda>(x)>

# %% [markdown]
# ### Step 6. Capitalize both Mjob and Fjob

# %%
stud_alcoh['Mjob'] = stud_alcoh['Mjob'].apply(capitalize)
stud_alcoh['Fjob'] = stud_alcoh['Fjob'].apply(capitalize)
stud_alcoh.head()
# Out:
#        sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# school
# GP       F   18       U     GT3       A     4     4  At_home   Teacher
# GP       F   17       U     GT3       T     1     1  At_home     Other
# GP       F   15       U     LE3       T     1     1  At_home     Other
# GP       F   15       U     GT3       T     4     2   Health  Services
# GP       F   16       U     GT3       T     3     3    Other     Other
#
#         reason guardian
# school
# GP      course   mother
# GP      course   father
# GP       other   mother
# GP        home   mother
# GP        home   father

# %% [markdown]
# ### Step 7. Print the last elements of the data set.

# %%
stud_alcoh.tail(1)
# Out:
#        sex  age address famsize Pstatus  Medu  Fedu   Mjob     Fjob  reason  \
# school
# MS       M   19       U     LE3       T     1     1  Other  At_home  course
#
#        guardian
# school
# MS       father

# %% [markdown]
# ### Step 8. Did you notice the original dataframe is still lowercase? Why is that? Fix it and capitalize Mjob and Fjob.

# %%
df['Mjob'] = df['Mjob'].apply(capitalize)
df['Fjob'] = df['Fjob'].apply(capitalize)
df.head()
# Out:
#        sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# school
# GP       F   18       U     GT3       A     4     4  At_home   Teacher
# GP       F   17       U     GT3       T     1     1  At_home     Other
# GP       F   15       U     LE3       T     1     1  At_home     Other
# GP       F   15       U     GT3       T     4     2   Health  Services
# GP       F   16       U     GT3       T     3     3    Other     Other
#
#         reason  ... famrel  freetime  goout  Dalc Walc health absences  G1  \
# school          ...
# GP      course  ...      4         3      4     1    1      3        6   5
# GP      course  ...      5         3      3     1    1      3        4   5
# GP       other  ...      4         3      2     2    3      3       10   7
# GP        home  ...      3         2      2     1    1      5        2  15
# GP        home  ...      4         3      2     1    2      5        4   6
#
#         G2  G3
# school
# GP       6   6
# GP       5   6
# GP       8  10
# GP      14  15
# GP      10  10
#
# [5 rows x 32 columns]

# %% [markdown]
# ### Step 9. Create a function called majority that returns a boolean value to a new column called legal_drinker (Consider majority as older than 17 years old)

# %%
def majority(age):
    return age > 17

# %%
df['legal_drinker'] = df['age'].apply(majority)
display(df.head())
# Out:
#        sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# school
# GP       F   18       U     GT3       A     4     4  At_home   Teacher
# GP       F   17       U     GT3       T     1     1  At_home     Other
# GP       F   15       U     LE3       T     1     1  At_home     Other
# GP       F   15       U     GT3       T     4     2   Health  Services
# GP       F   16       U     GT3       T     3     3    Other     Other
#
#         reason  ... freetime  goout  Dalc  Walc health absences  G1  G2  G3  \
# school          ...
# GP      course  ...        3      4     1     1      3        6   5   6   6
# GP      course  ...        3      3     1     1      3        4   5   5   6
# GP       other  ...        3      2     2     3      3       10   7   8  10
# GP        home  ...        2      2     1     1      5        2  15  14  15
# GP        home  ...        3      2     1     2      5        4   6  10  10
#
#        legal_drinker
# school
# GP              True
# GP             False
# GP             False
# GP             False
# GP             False
#
# [5 rows x 33 columns]

# %% [markdown]
# ### Step 10. Multiply every number of the dataset by 10.
# ##### I know this makes no sense, don't forget it is just an exercise

# %%
for col in df.columns:
    if df[col].dtype in ['int64', 'float64']:
        df[col] = df[col] * 10
display(df.head())
# Out:
#        sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# school
# GP       F  180       U     GT3       A    40    40  At_home   Teacher
# GP       F  170       U     GT3       T    10    10  At_home     Other
# GP       F  150       U     LE3       T    10    10  At_home     Other
# GP       F  150       U     GT3       T    40    20   Health  Services
# GP       F  160       U     GT3       T    30    30    Other     Other
#
#         reason  ... freetime  goout  Dalc  Walc health absences   G1   G2  \
# school          ...
# GP      course  ...       30     40    10    10     30       60   50   60
# GP      course  ...       30     30    10    10     30       40   50   50
# GP       other  ...       30     20    20    30     30      100   70   80
# GP        home  ...       20     20    10    10     50       20  150  140
# GP        home  ...       30     20    10    20     50       40   60  100
#
#          G3 legal_drinker
# school
# GP       60          True
# GP       60         False
# GP      100         False
# GP      150         False
# GP      100         False
#
# [5 rows x 33 columns]
